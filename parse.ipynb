# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Fayllarni o'qish va jadvallarga aylantirish
file_paths = ['data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_301.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_302.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_303.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_304.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_305.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_306.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_307.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_308.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_309.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_310.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_311.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_312.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_313.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_314.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_315.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_316.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_317.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_318.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_319.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_320.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_321.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_322.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_323.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_324.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_325.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_326.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_327.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_328.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_329.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_330.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_331.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_332.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_333.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_334.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_335.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_336.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_337.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_338.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_339.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_340.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_341.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_342.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_343.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_344.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_345.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_346.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_347.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_348.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_349.csv',
              'data/malumotlar/terabayt uz/terabayt uz/links_terabayt_uz_350.csv'
             ]
dataframes = [pd.read_csv(file_path) for file_path in file_paths]

# Jadvallarni birlashtirish
merged_dataframe = pd.concat(dataframes)
merged_dataframe


# Birlashtirilgan jadvalni saqlash
merged_dataframe.to_csv('merge.csv', index=False)

# %%
bbc_news_all=pd.read_csv("merge.csv")
bbc_news_all
# Out:
#                                                       0
# 0     https://www.terabayt.uz/post/ogoh-boling-windo...
# 1     https://www.terabayt.uz/post/340-dollarlik-rea...
# 2     https://www.terabayt.uz/post/redmi-k40-chiqish...
# 3     https://www.terabayt.uz/post/toshkentda-selfi-...
# 4     https://www.terabayt.uz/post/telefon-ekranidag...
# ...                                                 ...
# 3095  https://www.terabayt.uz/post/ommabop-smartfonl...
# 3096  https://www.terabayt.uz/post/one-ui-5-barqaror...
# 3097  https://www.terabayt.uz/post/one-ui-5-barqaror...
# 3098  https://www.terabayt.uz/post/iphone-se-4-rende...
# 3099  https://www.terabayt.uz/post/iphone-se-4-rende...
#
# [3100 rows x 1 columns]

# %% [markdown]
# # Linkini list ko'rinishda saqlash

# %%
a=bbc_news_all.loc[:50000].values.tolist()
a
# Out:
# [['https://www.terabayt.uz/post/ogoh-boling-windows-10-tizimli-kompyuter-va-noutbuklarni-ishdan-chiqaruvchi-havola-tarqaldi'],
#  ['https://www.terabayt.uz/post/340-dollarlik-realme-7-5g-smartfonini-2-kun-davomida-atigi-200-dollarga-olish-mumkin'],
#  ['https://www.terabayt.uz/post/redmi-k40-chiqishi-arafasida-kompaniyaning-tortta-bestselleri-arzonlashdi'],
#  ['https://www.terabayt.uz/post/toshkentda-selfi-qilmoqchi-bolgan-mehribonlik-uyi-tarbiyalanuvchisini-27-ming-volt-tok-urdi'],
#  ['https://www.terabayt.uz/post/telefon-ekranidagi-chiziqlardan-qutulishning-eng-oson-yollari'],
#  ['https://www.terabayt.uz/post/12-oylik-sovgalar-marafoni-har-oyda-playstation-4-apple-airpods-galaxy-watch-yoki-xbox-one-yutib-olishingiz-mumkin'],
#  ['https://www.terabayt.uz/post/linux-bazasida-ipados-kloni-yaratildi-jingos-planshet-va-noutbuklarga-keyin-smartfonlarga-chiqadi-video'],
#  ['https://www.terabayt.uz/post/raqamli-islohotlarning-texnologik-poydevori'],
# ...

# %%
b=[]
for i in a:
    b+=i
print(b)
# Out:
# ['https://www.terabayt.uz/post/ogoh-boling-windows-10-tizimli-kompyuter-va-noutbuklarni-ishdan-chiqaruvchi-havola-tarqaldi', 'https://www.terabayt.uz/post/340-dollarlik-realme-7-5g-smartfonini-2-kun-davomida-atigi-200-dollarga-olish-mumkin', 'https://www.terabayt.uz/post/redmi-k40-chiqishi-arafasida-kompaniyaning-tortta-bestselleri-arzonlashdi', 'https://www.terabayt.uz/post/toshkentda-selfi-qilmoqchi-bolgan-mehribonlik-uyi-tarbiyalanuvchisini-27-ming-volt-tok-urdi', 'https://www.terabayt.uz/post/telefon-ekranidagi-chiziqlardan-qutulishning-eng-oson-yollari', 'https://www.terabayt.uz/post/12-oylik-sovgalar-marafoni-har-oyda-playstation-4-apple-airpods-galaxy-watch-yoki-xbox-one-yutib-olishingiz-mumkin', 'https://www.terabayt.uz/post/linux-bazasida-ipados-kloni-yaratildi-jingos-planshet-va-noutbuklarga-keyin-smartfonlarga-chiqadi-video', 'https://www.terabayt.uz/post/raqamli-islohotlarning-texnologik-poydevori', 'https://www.terabayt.uz/post/top-10-eng-ravon-ishlovchi-smartfonlar-mast
# ...

# %%
# Web sahifani URL manzili
#url = 'https://effect.uz/926'

# Web sahifani HTML ma'lumotlarini olish
#response = requests.get(url)
#html_content = response.text

# BeautifulSoup kutubxonasini ishlatib HTML-ni parsing qilish
#soup = BeautifulSoup(html_content, 'html.parser')

# Matn elementlarini izlash va chiqarish
#matnlar = soup.find_all('p')  # Misol uchun <p> teglaridagi matnlarni izlaymiz

#for matn in matnlar:
 #   print(matn.text)

# %%
# Saytlar ro'yxati
urls = b

# Barcha matnlar uchun to'plangan ro'yxat
all_matnlar = []

for url in urls:
    # Web sahifani HTML ma'lumotlarini olish
    response = requests.get(url)
    html_content = response.text

    # BeautifulSoup kutubxonasini ishlatib HTML-ni parsing qilish
    soup = BeautifulSoup(html_content, 'html.parser')

    # Matn elementlarini izlash va ro'yxatga qo'shish
    matnlar = soup.find_all('p')  # Misol uchun <p> teglaridagi matnlarni izlaymiz
    all_matnlar.extend(matnlar)

# %% [markdown]
# # Matnlar faylga saqlanishi

# %%
for matn in all_matnlar:
    matn.text
    
with open('New_data/terabayt/links_terabayt_uz_301-350.txt.txt', 'w', encoding='utf-8') as file:
    for matn in all_matnlar:
        file.write(matn.text + '\n')

print("Matnlar faylga saqlandi: matnlar.txt")
